# %%
import pandas as pd

# %%
df = pd.read_excel('World_Development_Indicators.xlsx')

# %%
df.tail()
# Out:
#                                           Series Name Series Code  \
# 264                                               NaN         NaN
# 265                                               NaN         NaN
# 266                                               NaN         NaN
# 267  Data from database: World Development Indicators         NaN
# 268                          Last Updated: 03/21/2019         NaN
#
#     Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2009 [YR2009]  \
# 264          NaN          NaN           NaN           NaN           NaN
# 265          NaN          NaN           NaN           NaN           NaN
# 266          NaN          NaN           NaN           NaN           NaN
# 267          NaN          NaN           NaN           NaN           NaN
# 268          NaN          NaN           NaN           NaN           NaN
#
#     2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# ...

# %% [markdown]
# We need to filter the na rows or columns.

# %% [markdown]
# * Drop na of 'Series Name'

# %%
df.dropna(subset=['Series Name'],axis=0,inplace=True)

# %%
df.tail()
# Out:
#                                           Series Name     Series Code  \
# 261                                 GDP (current US$)  NY.GDP.MKTP.CD
# 262                                 GDP (current US$)  NY.GDP.MKTP.CD
# 263                                 GDP (current US$)  NY.GDP.MKTP.CD
# 267  Data from database: World Development Indicators             NaN
# 268                          Last Updated: 03/21/2019             NaN
#
#     Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2009 [YR2009]  \
# 261  Yemen, Rep.          YEM   5.64712e+09   9.65244e+09   2.51303e+10
# 262       Zambia          ZMB   3.28522e+09   3.60068e+09   1.53283e+10
# 263     Zimbabwe          ZWE    8783816700   6.68996e+09   9.66579e+09
# 267          NaN          NaN           NaN           NaN           NaN
# 268          NaN          NaN           NaN           NaN           NaN
#
#     2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# ...

# %% [markdown]
# The na rows of (264~266) were deleted.

# %% [markdown]
# * dropna columns if contain na

# %%
df2 = df.dropna(how='any',axis=1)

# %%
df2.head()
# Out:
#          Series Name
# 0  GDP (current US$)
# 1  GDP (current US$)
# 2  GDP (current US$)
# 3  GDP (current US$)
# 4  GDP (current US$)

# %% [markdown]
# OK,there are nan values in all columns.
